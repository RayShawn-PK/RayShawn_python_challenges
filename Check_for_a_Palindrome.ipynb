# %%
def check_palindrome(s=None):
    if s is None: 
        s = input("Enter a string to check: ")
    return s == s[::-1]

check_palindrome("racecar")
# Out:
# True

# %%
check_palindrome("tiger")
# Out:
# False
